# %%
import sys
# !{sys.executable} -m pip install pandas numpy

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth', None)

d = pd.read_json("cleaned_products.json")
d.head()
# Out:
#                                            title  \
# 0       Valco VMK25.2 vastamelukuulokkeet, Musta
# 1              Google Pixel 11 5G, 256 Gt, Frost
# 2         Google Pixel 11 Pro 5G, 256 Gt, Canyon
# 3  Google Pixel 11 Pro Fold 5G, 256 Gt, Obsidian
# 4      Google Pixel 11 Pro XL 5G, 256 Gt, Canyon
#
#                                                                          url  \
# 0      https://kauppa.dna.fi/tuote/p/valco-vmk25-2-vastamelukuulokkeet-musta
# 1              https://kauppa.dna.fi/tuote/p/google-pixel-11-5g-256-gt-frost
# 2         https://kauppa.dna.fi/tuote/p/google-pixel-11-pro-5g-256-gt-canyon
# 3  https://kauppa.dna.fi/tuote/p/google-pixel-11-pro-fold-5g-256-gt-obsidian
# 4      https://kauppa.dna.fi/tuote/p/google-pixel-11-pro-xl-5g-256-gt-canyon
#
#    price_eur  dna_price_eur  customer_price_eur  in_stock manufacturer  \
# 0     199.00         199.00              199.00      True        Valco
# ...

# %%
df = pd.DataFrame(d)
df
# Out:
#                                                              title  \
# 0                         Valco VMK25.2 vastamelukuulokkeet, Musta
# 1                                Google Pixel 11 5G, 256 Gt, Frost
# 2                           Google Pixel 11 Pro 5G, 256 Gt, Canyon
# 3                    Google Pixel 11 Pro Fold 5G, 256 Gt, Obsidian
# 4                        Google Pixel 11 Pro XL 5G, 256 Gt, Canyon
# ..                                                             ...
# 305      JBL Live Flex langattomat vastamelunappikuulokkeet, Musta
# 306                    JBL Wave Flex langattomat kuulokkeet, Beige
# 307                            EZVIZ BC1-B2 -valvontakamerapaketti
# 308     JBL Live Pro 2 langattomat vastamelunappikuulokkeet, Musta
# 309  JBL Tune Flex langattomat vastamelunappikuulokkeet, Valkoinen
#
#                                                                                             url  \
# ...

# %%
df[df["manufacturer"] == "Samsung"]
# Out:
#                                                   title  \
# 8                  Samsung Galaxy A27 5G, 256 Gt, Musta
# 9                  Samsung Galaxy A27 5G, 128 Gt, Musta
# 10        Samsung Galaxy Watch Ultra2 -älykello, Harmaa
# 11   Samsung Galaxy Watch9 eSIM -älykello, 40 mm, Hopea
# 12   Samsung Galaxy Watch9 eSIM -älykello, 44 mm, Hopea
# ..                                                  ...
# 264                           Samsung Galaxy A16, Black
# 272     Samsung Galaxy Fit3 -aktiivisuusranneke, Harmaa
# 282          Samsung Galaxy Watch Ultra, Titanium White
# 283  Samsung Galaxy Buds3 langattomat kuulokkeet, Hopea
# 284              Samsung Galaxy Watch7 4G, 40 mm, Green
#
#                                                                                           url  \
# 8                            https://kauppa.dna.fi/tuote/p/samsung-galaxy-a27-5g-256-gt-musta
# 9                            https://kauppa.dna.fi/tuote/p/samsung-galaxy-a27-5g-128-gt-musta
# ...

# %%
s26_ultra_df = df[df["title"].str.contains("S26 Ultra", case=False, na=False)]
s26_ultra_df
# Out:
#                                           title  \
# 98     Samsung Galaxy S26 Ultra 5G, 1 Tt, Black
# 99   Samsung Galaxy S26 Ultra 5G, 256 Gt, Black
# 100  Samsung Galaxy S26 Ultra 5G, 512 Gt, Black
#
#                                                                         url  \
# 98     https://kauppa.dna.fi/tuote/p/samsung-galaxy-s26-ultra-5g-1-tt-black
# 99   https://kauppa.dna.fi/tuote/p/samsung-galaxy-s26-ultra-5g-256-gt-black
# 100  https://kauppa.dna.fi/tuote/p/samsung-galaxy-s26-ultra-5g-512-gt-black
#
#      price_eur  dna_price_eur  customer_price_eur  in_stock manufacturer  \
# 98       14.99          14.99               14.99      True      Samsung
# 99       12.99          12.99               12.99      True      Samsung
# 100      13.99          13.99               13.99      True      Samsung
#
#                                             gift
# 98   Kaupan päälle jopa 399 € arvoinen tabletti!
# 99   Kaupan päälle jopa 399 € arvoinen tabletti!
# ...
