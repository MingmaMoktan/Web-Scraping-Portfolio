# %%
import pandas

# %%
data = pandas.read_json("/home/david_salome/mygitfolder/Web-Scraping-Portfolio/bookscraper/bookdata.json")

# %%
df = pandas.DataFrame(data)
df.head()
df.count()
# Out:
# url               967
# title             967
# product_type      967
# price_excl_tax    967
# price_incl_tax    967
# tax               967
# availability      967
# num_reviews       967
# stars             967
# category          967
# description       965
# price             967
# dtype: int64
